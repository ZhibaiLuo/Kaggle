# %%
import numpy as np 
import pandas as pd 
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
for dirname, _, filenames in os.walk('./'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./Hotel_bookings.ipynb
# ./.ipynb_checkpoints/Hotel_bookings-checkpoint.ipynb
# ./data/hotel_bookings.csv
# ./data/data_arr_df.csv
# ./data/pca_data_arr_df.csv

# %%
hotel_booking = pd.read_csv('./data/hotel_bookings.csv')
display(hotel_booking.head(8).T)
print(hotel_booking.info())
display(hotel_booking.describe().T)
# Out:
#                                            0             1             2  \
# hotel                           Resort Hotel  Resort Hotel  Resort Hotel
# is_canceled                                0             0             0
# lead_time                                342           737             7
# arrival_date_year                       2015          2015          2015
# arrival_date_month                      July          July          July
# arrival_date_week_number                  27            27            27
# arrival_date_day_of_month                  1             1             1
# stays_in_weekend_nights                    0             0             0
# stays_in_week_nights                       0             0             1
# adults                                     2             2             1
# children                                   0             0             0
# babies                                     0             0             0
# ...

# %% [markdown]
# # EDA

# %%
import seaborn as sns
sns.countplot(x = 'reservation_status', data = hotel_booking)

# %%
plt.figure(figsize=(10,4))
sns.distplot(hotel_booking['stays_in_weekend_nights'],
             label = "Weekend nights stays",axlabel = False, kde = False, bins = 30)
sns.distplot(hotel_booking['stays_in_week_nights'],
             label = "Week nights stays",axlabel = False, kde = False, bins = 50)
plt.xlim(0,15)
plt.legend()

# %%
sns.boxplot(x = 'reservation_status',y = 'stays_in_weekend_nights',data = hotel_booking)

# %%
sns.boxplot(x = 'reservation_status',y = 'stays_in_week_nights',data = hotel_booking)

# %%
sns.boxplot(x = 'reservation_status',y = 'lead_time',data = hotel_booking)

# %%
plt.figure(figsize=(16,5))
sns.countplot(x = 'arrival_date_month', data = hotel_booking, hue = 'reservation_status')

# %%
hotel_booking['total_guests'] = hotel_booking['adults'] + hotel_booking['children'] + hotel_booking['babies']
plt.figure(figsize=(15,5))
sns.countplot(x = 'total_guests', data = hotel_booking, hue = 'reservation_status')

# %%
fig, ax =plt.subplots(nrows=1, ncols=3, figsize=(20,8))
g=sns.countplot(x = 'adults', data = hotel_booking, hue = 'reservation_status',ax=ax[0])
g.legend_.remove()
g=sns.countplot(x = 'children', data = hotel_booking, hue = 'reservation_status',ax=ax[1])
g.legend_.remove()
g=sns.countplot(x = 'babies', data = hotel_booking, hue = 'reservation_status',ax=ax[2])
g.legend(loc='right', bbox_to_anchor=(1.4, 0.5), ncol=1)
fig.show()
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
hotel_booking._get_numeric_data().columns
# Out:
# Index(['is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_week_number', 'arrival_date_day_of_month',
#        'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
#        'babies', 'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company',
#        'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'total_guests'],
#       dtype='object')

# %% [markdown]
# ## Use Cramer V Statistics to draw the correlation heatmap of categorical variables

# %%
hotel_booking = pd.read_csv('./data/hotel_bookings.csv')
hotel_booking = hotel_booking.drop('reservation_status',axis=1)
hotel_booking['is_canceled'] = hotel_booking['is_canceled'].replace([0,1],["no","yes"])
cols = hotel_booking.columns
num_cols = hotel_booking._get_numeric_data().columns
cat_cols=list(set(cols) - set(num_cols))
hotel_booking_cat = hotel_booking[cat_cols]
hotel_booking_cat.head().T
# Out:
#                                     0             1             2  \
# assigned_room_type                  C             C             C
# reserved_room_type                  C             C             A
# meal                               BB            BB            BB
# market_segment                 Direct        Direct        Direct
# country                           PRT           PRT           GBR
# customer_type               Transient     Transient     Transient
# deposit_type               No Deposit    No Deposit    No Deposit
# reservation_status_date    2015-07-01    2015-07-01    2015-07-02
# arrival_date_month               July          July          July
# is_canceled                        no            no            no
# hotel                    Resort Hotel  Resort Hotel  Resort Hotel
# distribution_channel           Direct        Direct        Direct
#
#                                     3             4
# assigned_room_type                  A             A
# ...

# %%
import itertools
import scipy

def cramers_corrected_stat(confusion_matrix):
    """
    Calculates the corrected Cramer's V statistic
    
    Args:
        confusion_matrix: The confusion matrix of the variables to calculate the statistic on
    
    Returns:
        The corrected Cramer's V statistic
    """
    
    #chi2, _, _, _ = scipy.stats.chi2_contingency(confusion_matrix)
    chi2 = scipy.stats.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

#Getting the list of columns in the dataframe
cols = list(hotel_booking_cat.columns.values)

#Creating an empty array to append to as we will go through iteratations to calculate correlations of every combination of variables.
emp_arr = np.zeros((len(cols),len(cols)))

#Iteraiting dataframe using itertools
#itertools.combinations() : Given an array of size n, generate and print all possible combinations of r elements in array.
for col1, col2 in itertools.combinations(cols, 2):
    A, B = hotel_booking_cat[col1], hotel_booking_cat[col2]
    idx1, idx2 = cols.index(col1), cols.index(col2)
    conf_mat = pd.crosstab(A,B) 
    #appending results to emp_array
    emp_arr[idx1, idx2] = cramers_corrected_stat(conf_mat.values)
    emp_arr[idx2, idx1] = emp_arr[idx1, idx2]

#creating a correlation matrix
corr = pd.DataFrame(emp_arr, index=cols, columns=cols)

# Mask to get lower triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

cmap = sns.cubehelix_palette(light=1, as_cmap=True)

# Draw the heatmap with the mask 
fig = plt.figure(figsize=(12, 12))

sns.heatmap(corr, mask=mask, cmap=cmap, square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='deposit_type',data=hotel_booking_cat,hue='is_canceled')
# sns.countplot(x='reservation_status_date',data=hotel_booking_cat,hue='is_canceled')

# %%
hotel_booking = pd.read_csv('./data/hotel_bookings.csv')
plt.figure(figsize=(20,10))
sns.heatmap(hotel_booking.corr(),annot=True,cmap='viridis')

# %%
hotel_booking.corr()['is_canceled'].sort_values().plot(kind='bar')

# %%
sns.boxplot(x = 'reservation_status',y = 'total_of_special_requests',data = hotel_booking)

# %%
X_cat = hotel_booking_cat.drop("is_canceled", axis=1)
y_cat = hotel_booking_cat["is_canceled"].eq('yes').mul(1)
X_cat['country'].fillna('No Country', inplace = True)
X_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 11 columns):
# assigned_room_type         119390 non-null object
# reserved_room_type         119390 non-null object
# meal                       119390 non-null object
# market_segment             119390 non-null object
# country                    119390 non-null object
# customer_type              119390 non-null object
# deposit_type               119390 non-null object
# reservation_status_date    119390 non-null object
# arrival_date_month         119390 non-null object
# hotel                      119390 non-null object
# distribution_channel       119390 non-null object
# dtypes: object(11)
# memory usage: 10.0+ MB

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

def labelencode(df):
    le = LabelEncoder()
    return df.apply(le.fit_transform)

def onehotencode(df):
    onehot = OneHotEncoder()
    return onehot.fit_transform(df).toarray()
# transform categorical into [0,1,2,3]
X_2 = labelencode(X_cat)
# one hot encoding
onehotlabels = onehotencode(X_2)

# one hot encoding generating much dimention, PCA is necessary
print(X_2.shape)
print(onehotlabels.shape)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# (119390, 11)
# (119390, 1165)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)

# Perform PCA on the one-hot encoded labels
X_pca = pca.fit_transform(onehotlabels)

ex_variance=np.var(X_pca,axis=0)
ex_variance_ratio = ex_variance/np.sum(ex_variance)
print(ex_variance_ratio)
# Out:
# [0.44257446 0.32937114 0.2280544 ]

# %%
# pca_cat = PCA(n_components=len(hotel_booking_cat.columns))
pca_cat = PCA(n_components=1165)

# Perform PCA on the one-hot encoded labels
pca_onehotlabels = pca_cat.fit_transform(onehotlabels)

# Rebuild it in its original dimension
X_pca_reconst = pca_cat.inverse_transform(pca_onehotlabels)

#plotting

plt.figure(figsize=(12,12))

plt.scatter(pca_onehotlabels[y_cat==0, 0], pca_onehotlabels[y_cat==0, 1], color='red', alpha=0.5,label='Not canceled')
plt.scatter(pca_onehotlabels[y_cat==1, 0], pca_onehotlabels[y_cat==1, 1], color='blue', alpha=0.5,label='Canceled')

plt.title("PCA")
plt.ylabel('Principal component Y')
plt.xlabel('Principal component X')
plt.legend()
plt.show()

# %%
# pca = PCA(n_components=len(hotel_booking_cat.columns))
# X_pca = pca.fit_transform(onehotlabels)

percentage_var_explained = pca_cat.explained_variance_ / np.sum(pca_cat.explained_variance_);
cum_var_explained = np.cumsum(percentage_var_explained)
print(cum_var_explained)

# Plot the PCA spectrum
plt.figure(1, figsize=(6, 4))
plt.clf()
plt.plot(cum_var_explained, linewidth=2)
plt.grid()
plt.xlabel('n_components')
plt.ylabel('Cumulative_explained_variance')
plt.show()
# Out:
# [0.12013401 0.2095397  0.27144361 ... 1.         1.         1.        ]

# %%
#getting the numerical feature columns one more time
cols = hotel_booking.columns
num_cols = hotel_booking._get_numeric_data().columns

#selecting numerical features
hotel_booking_num = hotel_booking[num_cols].drop('is_canceled',axis=1)
hotel_booking_num = hotel_booking_num.fillna(hotel_booking_num.median())

#selecting target ('is_canceled' column)
y_num=y_cat

# %%
from sklearn.preprocessing import StandardScaler
# Standardizing the features
hotel_booking_num_standard = StandardScaler().fit_transform(hotel_booking_num.values)

#replacing the X_num dataframe with the standardized dataframe
hotel_booking_num[:] = hotel_booking_num_standard

# %%
pca_num = PCA(n_components=len(hotel_booking_num.columns))

# Perform PCA on the one-hot encoded labels
pca_hotel_booking_num = pca_num.fit_transform(hotel_booking_num)

#plotting

plt.figure(figsize=(12,12))

plt.scatter(pca_hotel_booking_num[y_num==0, 0], pca_hotel_booking_num[y_num==0, 1], color='red', alpha=0.5,label='Not canceled')
plt.scatter(pca_hotel_booking_num[y_num==1, 0], pca_hotel_booking_num[y_num==1, 1], color='blue', alpha=0.5,label='Canceled')

plt.title("PCA")
plt.ylabel('Principal component Y')
plt.xlabel('Principal component X')
plt.legend()
plt.show()

# %%
percentage_var_explained = pca_num.explained_variance_ / np.sum(pca_num.explained_variance_);
cum_var_explained = np.cumsum(percentage_var_explained)
print(cum_var_explained)
# Plot the PCA spectrum
plt.figure(1, figsize=(6, 4))
plt.clf()
plt.plot(cum_var_explained, linewidth=2)
plt.grid()
plt.xlabel('n_components')
plt.ylabel('Cumulative_explained_variance')
plt.show()
# Out:
# [0.10427388 0.19306847 0.27170156 0.34712673 0.41070511 0.46765419
#  0.52198928 0.57468932 0.62711359 0.67779336 0.72591749 0.77082444
#  0.81326857 0.85414216 0.8932585  0.92724035 0.95674951 0.98256259
#  1.        ]

# %%
print(hotel_booking_num_standard.shape, type(hotel_booking_num_standard))
print(pca_hotel_booking_num.shape, type(pca_hotel_booking_num))
print(onehotlabels.shape, type(onehotlabels))
print(pca_onehotlabels.shape, type(pca_onehotlabels))
y = y_cat.values[:,np.newaxis]
print(y.shape, type(y))
# Out:
# (119390, 19) <class 'numpy.ndarray'>
# (119390, 19) <class 'numpy.ndarray'>
# (119390, 1165) <class 'numpy.ndarray'>
# (119390, 1165) <class 'numpy.ndarray'>
# (119390, 1) <class 'numpy.ndarray'>

# %%
data_arr = np.concatenate([y,hotel_booking_num_standard,onehotlabels], axis = 1)
print(data_arr.shape)
data_arr_df = pd.DataFrame(data_arr)
data_arr_df.to_csv('./data/data_arr_df.csv', header = False, index = False)
# Out:
# (119390, 1185)

# %%
pca_x_arr = np.concatenate([y,pca_hotel_booking_num[:,:17],pca_onehotlabels[:,:401]], axis = 1)
print(pca_x_arr.shape)
pca_data_arr_df = pd.DataFrame(pca_x_arr)
pca_data_arr_df.to_csv('./data/pca_data_arr_df.csv', header = False, index = False)
# Out:
# (119390, 419)
